#   inflating: __MACOSX/videos/roll_up/._23KFJJfam7rzU.mkv
#   inflating: videos/roll_up/48jIt5PdXtkSQ.mkv
#   inflating: __MACOSX/videos/roll_up/._48jIt5PdXtkSQ.mkv
#   inflating: videos/roll_up/15WnsLNQFCnD8.mkv
#   inflating: __MACOSX/videos/roll_up/._15WnsLNQFCnD8.mkv
#   inflating: videos/roll_up/31QXZ4GZI9XfI.mkv
#   inflating: __MACOSX/videos/roll_up/._31QXZ4GZI9XfI.mkv
#   inflating: videos/roll_up/49l_rSeNryizA.mkv
#   inflating: __MACOSX/videos/roll_up/._49l_rSeNryizA.mkv
#   inflating: videos/roll_up/22fsSWSl-ty2E.mkv
#   inflating: __MACOSX/videos/roll_up/._22fsSWSl-ty2E.mkv
#   inflating: videos/roll_up/14cO0QWKTlXy8.mkv
#   inflating: __MACOSX/videos/roll_up/._14cO0QWKTlXy8.mkv
#   inflating: videos/roll_up/44z273-hUsvEg.mkv
#   inflating: __MACOSX/videos/roll_up/._44z273-hUsvEg.mkv
#   inflating: videos/roll_up/6wjbN81QqNZs.mkv
#   inflating: __MACOSX/videos/roll_up/._6wjbN81QqNZs.mkv
#   inflating: __MACOSX/videos/._roll_up
#   inflating: __MACOSX/._videos

# %%
# !rm -rf __MACOSX/

# %%
# FRAME EXTRACTION

import os
from tqdm import tqdm
import cv2
import pandas as pd
import sys

def create_folder(folder_name):
    """
    :param folder_name: the folder name
    Creates that folder if not exist
    """
    if not os.path.isdir(folder_name):
        os.mkdir(folder_name)  # make sure the directory exists


def get_video_data(videos_path):
    """
    :param videos_path: gets a path of videos, a folder that contains all the videos
    :return: A dataframe that contains all the videos' names and their class (class = in what folder they exists)

    For example: name: video_1.mkv tag: criss_cross video_1.mkv (name of the video) is under the sub-folder named
    criss_cross, this folder is under the folder stated in videos_path.
    """

    videos_tags_list = []
    for exercise_folder in os.listdir(path=videos_path):
        if not exercise_folder.startswith('.'):  # skip hidden files
            for video in os.listdir(path=f'{videos_path}/{exercise_folder}'):
                videos_tags_list.append({'name': video, 'tag': exercise_folder})

    video_df = pd.DataFrame(data=videos_tags_list)

    return video_df


def create_folders_and_sub_folders(folder_name, sub_folder_list):
    """
    :param sub_folder_list: sub folders
    :param folder_name: folder name
    :param subfolder_list: list of sub folders to be created
    :return: creates a folder, and after that sub-folders in it
    """

    create_folder(f'{folder_name}')

    for sub_folder in sub_folder_list:
        create_folder(f'{folder_name}/{sub_folder}')


def extract_frames(videos_path, frames_path, df):
    """
    :param videos_path: the video path
    :param frames_path: the frames path
    :param df: dataframe that contains the video data
    :return:
    """

    # indexes 0 and 1, for the list
    NAME = 0
    TAG = 1

    # Frame rate
    FRAMES = 20
    # Max attempts before it will give up?
    MAX_ATTEMPTS = 10

    # storing the frames from training videos
    counter_videos = 0
    frame_videos_list = []
    for video in tqdm(df.itertuples(index=False)):
        counter_frames = 0
        counter_attempts = 0
        video_path = f'{videos_path}/{video[TAG]}/{video[NAME]}'
        cap = cv2.VideoCapture(video_path)  # capturing the video from the given path
        while cap.isOpened():
            ret, frame = cap.read()
            if ret is False:
                if counter_attempts < MAX_ATTEMPTS:
                    counter_attempts += 1
                    continue
                else:
                    break
            if counter_frames < FRAMES:
                # storing the frames in a new folder named train
                filename = f'{frames_path}/{video[TAG]}/video{counter_videos}_frame{counter_frames}.jpg'
                counter_frames += 1
                cv2.imwrite(filename, frame)
                frame_videos_list.append({'video': video[NAME], 'image': filename, 'class': video[TAG]})
        counter_videos += 1
    cap.release()
    print('Done reading the videos and writing the frames')
    return frame_videos_list

def get_frames_from_folders():
    """
    Run this if you are already finished the extraction and want to load exsisting frames
    :return: dataframe with data on the frames
    """

    videos_path = 'videos'
    frame_path = 'frames'
    video_df = get_video_data(videos_path=videos_path)

    videos_list = extract_frames(videos_path=videos_path, frames_path=frame_path, df=video_df)
    frames_data = pd.DataFrame(videos_list)
    return frames_data

def get_frames_from_videos():
    """
    Creates the frames from videos
    :return: a frame dataframe contains data on the extracted frames: video name, frame name, class.
    """
    # Get the videos' names and their classes
    videos_path = './videos'
    frame_path = 'frames'

    video_df = get_video_data(videos_path=videos_path)

    # Set tags as the list of unique classes
    tags = list(video_df['tag'].unique())
    sub_folder_list = ['criss_cross', 'double_leg', 'roll_up']

    create_folders_and_sub_folders(folder_name=frame_path, sub_folder_list=sub_folder_list)

    videos_list = extract_frames(videos_path=videos_path, frames_path=frame_path, df=video_df)
    frames_data = pd.DataFrame(videos_list)
    print('Finished frame extraction')
    return frames_data

# %%
# SPLIT PROCESS

from sklearn.model_selection import StratifiedGroupKFold
import numpy as np
from tqdm import tqdm
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import preprocess_input
import pandas as pd


def split_data(data):
    train_inds, test_inds = next(
        StratifiedGroupKFold(shuffle=True, random_state=28)\
        .split(data, y=data['class'], groups=data['video']))

    train_data = data.iloc[train_inds].reset_index()
    test_data = data.iloc[test_inds].reset_index()
    return train_data, test_data


def images_to_array_with_classes(data):
    """
    :param data: a data set of images
    :return:
    """

    SAMPLES = 0
    X = np.empty((data.shape[SAMPLES], 224, 224, 3))
    # for loop to read and store frames
    for i in tqdm(range(data.shape[SAMPLES])):
        # loading the image and keeping the target size as (224,224,3)
        img = image.load_img(data['image'][i], target_size=(224, 224, 3))
        # converting it to array
        img = image.img_to_array(img)
        # normalizing the pixel value
        # img = img/255
        # appending the image to the train_image list
        X[i] = img
    X = preprocess_input(np.array(X))
    y = pd.get_dummies(data['class'])
    y = data['class']

    return X, y

# %%
# TRAINING

from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import  ImageDataGenerator
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

def model_initiation():
    base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
    base_model.trainable = False  ## Not trainable weights
    model = Sequential([base_model])
    model.add(Flatten())
    model.add(Dense(1024, activation='relu', input_shape=(25088,)))
    model.add(Dropout(0.5))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(3, activation='softmax'))
    return model

def create_model(optimizer='adam'):
    model = model_initiation()
    model.compile(loss='sparse_categorical_crossentropy', 
                  optimizer=optimizer,
                  metrics=['accuracy'])
    return model

def hypertuning(X_train, y_train, groups):
    print('Begin setting up')
    model = KerasClassifier(build_fn=create_model, verbose=2)

    epochs = [10, 20, 40]
    batch_size = [8, 16, 32]
    optimizer = ['rmsprop','adam']
    # init_mode = ['uniform', 'lecun_uniform', 'normal', 'zero', 
    #          'glorot_normal', 'glorot_uniform', 'he_normal', 'he_uniform']
    # epochs = [1]
    # batch_size = [8]
    # optimizer = [RMSprop((momentum=0.95))]
    param_distributions = dict(epochs=epochs, batch_size=batch_size,
                               optimizer=optimizer, 
                            #   init_mode=init_mode,
                              )

    N_SPLITS = 5

    print('Cross Validating...')
    rscv = RandomizedSearchCV(estimator=model, 
                              param_distributions=param_distributions,
                              n_iter=10,
                              cv=StratifiedGroupKFold(n_splits=N_SPLITS, 
                                                      shuffle=True,
                                                      random_state=28),
                              random_state=28)
    rscv.fit(X=X_train, y=y_train, groups=groups)
    print(rscv.cv_results_)
    print()
    print(rscv.best_score_)
    print()
    print(rscv.best_params_)
    print()
    print(rscv.best_index_)
    print()
    print(rscv.scorer_)
    print('End setting up')
    return rscv.best_params_

def train(X_train, y_train, best_params):

    print('Begin training with the best parameters')
    mcp_save = ModelCheckpoint('weight.hdf55', save_best_only=True, monitor='accuracy')
    es = EarlyStopping( monitor='accuracy', patience=5, restore_best_weights=True)
    tb = TensorBoard(log_dir='logs')
    model = KerasClassifier(build_fn=create_model, verbose=2, 
                            optimizer=best_params['optimizer'])
    model.fit(x=X_train, y=y_train, 
              epochs=best_params['epochs']+3, 
              batch_size=best_params['batch_size'],
              callbacks=[mcp_save, es, tb])
    print('End training')
    return

# %%
# TESTING

from tqdm import tqdm
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.models import load_model
import numpy as np
from sklearn.metrics import accuracy_score
from scipy import stats
# from frame_extraction import get_video_data as vd
import pandas as pd

ONLY = 0


def test(test_data, y_test):
    y_test = pd.get_dummies(y_test)
    model = load_model('weight.hdf55')
    videos_path = './videos'

    # video_data = vd(videos_path)
    video_data = get_video_data(videos_path)

    # creating two lists to store predicted and actual tags
    predict = []
    actual = []
    for video in tqdm(test_data['video'].unique()):

        prediction_images = []
        for frame in test_data.loc[test_data['video'] == video, 'image']:
            img = image.load_img(frame, target_size=(224, 224, 3))
            img = image.img_to_array(img)
            prediction_images.append(img)

        prediction_images = preprocess_input(np.array(prediction_images))
        prediction = np.argmax(model.predict(prediction_images), axis=-1)
        # appending the mode of predictions in predict list to assign the tag to the video
        predict.append(y_test.columns.values[stats.mode(prediction)[ONLY][ONLY]])
        actual.append(video_data.loc[video_data['name'] == video, 'tag'].iloc[ONLY])
    return predict, actual

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score
# import frame_extraction
#import split_preprocess
import pandas as pd
# import training
# import testing
import numpy as np
import sys

def test_func():
    test_data = pd.read_csv('test.csv')
    y_test = test_data['class']

    # predict, actual = testing.test(test,y_test)
    predict, actual = test(test_data, y_test)

    print(accuracy_score(predict, actual) * 100)
    return

def train_func():
    # If this is your first time creating frames use this:

    #frame_data = frame_extraction.get_frames_from_videos()
    # frame_data = get_frames_from_videos()

    # if you already have frames and want to load them
    # frame_data = frame_extraction.get_frames_from_folders()
    frame_data = get_frames_from_folders()

    # train, test = split_preprocess.split_data(frame_data)
    # X_train, y_train = split_preprocess.images_to_array_with_classes(train)
    # X_test, y_test = split_preprocess.images_to_array_with_classes(test)
    train_data, test_data = split_data(frame_data)

    X_train, y_train = images_to_array_with_classes(train_data)
    X_test, y_test = images_to_array_with_classes(test_data)
    
    le = LabelEncoder()
    y_train = le.fit_transform(y_train)
    y_test = le.transform(y_test)

    # test.to_csv('test.csv')
    # training.train(X_train, y_train, best_parameters)

    test_data.to_csv('test.csv')
    # train(X_train, y_train)
    return X_train, y_train, train_data['video']

# %%
# if __name__ == '__main__':

#     X_test, y_test = train_func()
#     # test_func()

X_train, y_train, groups = train_func()
best_params = hypertuning(X_train, y_train, groups)
train(X_train, y_train, best_params)

# test_func()
# Out:
# 158it [01:36,  1.63it/s]
# Done reading the videos and writing the frames
# 100%|██████████| 2431/2431 [00:24<00:00, 98.57it/s]
# 100%|██████████| 605/605 [00:06<00:00, 100.09it/s]
# Begin setting up
# Cross Validating...
# Epoch 1/40
# 120/120 - 9s - loss: 675.4638 - accuracy: 0.4545
# Epoch 2/40
# 120/120 - 4s - loss: 9.8203 - accuracy: 0.3438
# Epoch 3/40
# 120/120 - 4s - loss: 7.3519 - accuracy: 0.3610
# Epoch 4/40
# 120/120 - 4s - loss: 9.8965 - accuracy: 0.3459
# Epoch 5/40
# 120/120 - 4s - loss: 2.4650 - accuracy: 0.3454
# Epoch 6/40
# 120/120 - 4s - loss: 13.6098 - accuracy: 0.3433
# Epoch 7/40
# 120/120 - 4s - loss: 11.8423 - accuracy: 0.3521
# Epoch 8/40
# 120/120 - 4s - loss: 1.0979 - accuracy: 0.3474
# Epoch 9/40
# 120/120 - 4s - loss: 6.3251 - accuracy: 0.3542
# Epoch 10/40
# 120/120 - 4s - loss: 3.6252 - accuracy: 0.3474
# Epoch 11/40
# 120/120 - 4s - loss: 1.2988 - accuracy: 0.3574
# Epoch 12/40
# 120/120 - 4s - loss: 3.0453 - accuracy: 0.3422
# Epoch 13/40
# 120/120 - 4s - loss: 1.0969 - accuracy: 0.3558
# Epoch 14/40
# 120/120 - 4s - loss: 1.0973 - accuracy: 0.3454
# Epoch 15/40
# 120/120 - 4s - loss: 1.1985 - accuracy: 0.3401
# Epoch 16/40
# 120/120 - 4s - loss: 1.2311 - accuracy: 0.3725
# Epoch 17/40
# 120/120 - 4s - loss: 1.6193 - accuracy: 0.3626
# Epoch 18/40
# 120/120 - 4s - loss: 7.6866 - accuracy: 0.3495
# Epoch 19/40
# 120/120 - 4s - loss: 1.0963 - accuracy: 0.3574
# Epoch 20/40
# 120/120 - 4s - loss: 1.0959 - accuracy: 0.3642
# Epoch 21/40
# 120/120 - 4s - loss: 1.1155 - accuracy: 0.3433
# Epoch 22/40
# 120/120 - 4s - loss: 1.4573 - accuracy: 0.3662
# Epoch 23/40
# 120/120 - 4s - loss: 1.0956 - accuracy: 0.3615
# Epoch 24/40
# 120/120 - 4s - loss: 1.0982 - accuracy: 0.3626
# Epoch 25/40
# 120/120 - 4s - loss: 1.0962 - accuracy: 0.3521
# Epoch 26/40
# 120/120 - 4s - loss: 2.0065 - accuracy: 0.3584
# Epoch 27/40
# 120/120 - 4s - loss: 1.0977 - accuracy: 0.3417
# Epoch 28/40
# 120/120 - 4s - loss: 1.0973 - accuracy: 0.3427
# Epoch 29/40
# 120/120 - 4s - loss: 1.2614 - accuracy: 0.3323
# Epoch 30/40
# 120/120 - 4s - loss: 2.9723 - accuracy: 0.3605
# Epoch 31/40
# 120/120 - 4s - loss: 1.0965 - accuracy: 0.3511
# Epoch 32/40
# 120/120 - 4s - loss: 2.7225 - accuracy: 0.3542
# Epoch 33/40
# 120/120 - 4s - loss: 1.0963 - accuracy: 0.3391
# Epoch 34/40
# 120/120 - 4s - loss: 1.0972 - accuracy: 0.3584
# Epoch 35/40
# 120/120 - 4s - loss: 1.0970 - accuracy: 0.3469
# Epoch 36/40
# 120/120 - 4s - loss: 1.0974 - accuracy: 0.3584
# Epoch 37/40
# 120/120 - 4s - loss: 1.0966 - accuracy: 0.3615
# Epoch 38/40
# 120/120 - 4s - loss: 1.0971 - accuracy: 0.3469
# Epoch 39/40
# 120/120 - 4s - loss: 1.0961 - accuracy: 0.3474
# Epoch 40/40
# 120/120 - 4s - loss: 1.0969 - accuracy: 0.3349
# 33/33 - 2s - loss: 1.0957 - accuracy: 0.3868
# Epoch 1/40
# 123/123 - 6s - loss: 885.1381 - accuracy: 0.4982
# Epoch 2/40
# 123/123 - 4s - loss: 29.5422 - accuracy: 0.3634
# Epoch 3/40
# 123/123 - 4s - loss: 12.3535 - accuracy: 0.3603
# Epoch 4/40
# 123/123 - 4s - loss: 8.0053 - accuracy: 0.3776
# Epoch 5/40
# 123/123 - 4s - loss: 5.2400 - accuracy: 0.3557
# Epoch 6/40
# 123/123 - 4s - loss: 15.7306 - accuracy: 0.3583
# Epoch 7/40
# 123/123 - 4s - loss: 2.2737 - accuracy: 0.3613
# Epoch 8/40
# 123/123 - 4s - loss: 1.1129 - accuracy: 0.3603
# Epoch 9/40
# 123/123 - 4s - loss: 16.6998 - accuracy: 0.3598
# Epoch 10/40
# 123/123 - 4s - loss: 2.1410 - accuracy: 0.3720
# Epoch 11/40
# 123/123 - 4s - loss: 1.0943 - accuracy: 0.3613
# Epoch 12/40
# 123/123 - 4s - loss: 2.2376 - accuracy: 0.3690
# Epoch 13/40
# 123/123 - 4s - loss: 2.0131 - accuracy: 0.3608
# Epoch 14/40
# 123/123 - 4s - loss: 4.2862 - accuracy: 0.3603
# Epoch 15/40
# 123/123 - 4s - loss: 1.8891 - accuracy: 0.3567
# Epoch 16/40
# 123/123 - 4s - loss: 1.0914 - accuracy: 0.3705
# Epoch 17/40
# 123/123 - 4s - loss: 1.1056 - accuracy: 0.3649
# Epoch 18/40
# 123/123 - 4s - loss: 12.6705 - accuracy: 0.3613
# Epoch 19/40
# 123/123 - 4s - loss: 3.5863 - accuracy: 0.3644
# Epoch 20/40
# 123/123 - 4s - loss: 1.1415 - accuracy: 0.3644
# Epoch 21/40
# 123/123 - 4s - loss: 1.2411 - accuracy: 0.3593
# Epoch 22/40
# 123/123 - 4s - loss: 8.6731 - accuracy: 0.3623
# Epoch 23/40
# 123/123 - 4s - loss: 6.2970 - accuracy: 0.3664
# Epoch 24/40
# 123/123 - 4s - loss: 2.0032 - accuracy: 0.3674
# Epoch 25/40
# Epoch 10/40
# 240/240 - 6s - loss: 3.0937 - accuracy: 0.3391
# Epoch 11/40
# 240/240 - 6s - loss: 1.0965 - accuracy: 0.3568
# Epoch 12/40
# 240/240 - 6s - loss: 8.1066 - accuracy: 0.3474
# Epoch 13/40
# 240/240 - 6s - loss: 2.7603 - accuracy: 0.3433
# Epoch 14/40
# 240/240 - 6s - loss: 10.5368 - accuracy: 0.3349
# Epoch 15/40
# 240/240 - 6s - loss: 1.0992 - accuracy: 0.3318
# Epoch 16/40
# 240/240 - 6s - loss: 2.5015 - accuracy: 0.3386
# Epoch 17/40
# 240/240 - 6s - loss: 3.5285 - accuracy: 0.3454
# Epoch 18/40
# 240/240 - 6s - loss: 1.0996 - accuracy: 0.3438
# Epoch 19/40
# 240/240 - 6s - loss: 1.0992 - accuracy: 0.3464
# Epoch 20/40
# 240/240 - 6s - loss: 1.4617 - accuracy: 0.3391
# Epoch 21/40
# 240/240 - 6s - loss: 1.0979 - accuracy: 0.3433
# Epoch 22/40
# 240/240 - 6s - loss: 1.1355 - accuracy: 0.3501
# Epoch 23/40
# 240/240 - 6s - loss: 16.3840 - accuracy: 0.3448
# Epoch 24/40
# 240/240 - 6s - loss: 3.0826 - accuracy: 0.3297
# Epoch 25/40
# 240/240 - 6s - loss: 1.0968 - accuracy: 0.3459
# Epoch 26/40
# 240/240 - 6s - loss: 1.1086 - accuracy: 0.3480
# Epoch 27/40
# 240/240 - 6s - loss: 1.0987 - accuracy: 0.3396
# Epoch 28/40
# 240/240 - 6s - loss: 3.1146 - accuracy: 0.3286
# Epoch 29/40
# 240/240 - 6s - loss: 1.0970 - accuracy: 0.3642
# Epoch 30/40
# 240/240 - 6s - loss: 12.1243 - accuracy: 0.3506
# Epoch 31/40
# 240/240 - 6s - loss: 3.1081 - accuracy: 0.3485
# Epoch 32/40
# 240/240 - 6s - loss: 1.0986 - accuracy: 0.3480
# Epoch 33/40
# 240/240 - 6s - loss: 1.2180 - accuracy: 0.3406
# Epoch 34/40
# 240/240 - 6s - loss: 1.0971 - accuracy: 0.3506
# Epoch 35/40
# 240/240 - 6s - loss: 1.0960 - accuracy: 0.3511
# Epoch 36/40
# 240/240 - 6s - loss: 1.0987 - accuracy: 0.3501
# Epoch 37/40
# 240/240 - 6s - loss: 2.2437 - accuracy: 0.3490
# Epoch 38/40
# 240/240 - 6s - loss: 1.0979 - accuracy: 0.3448
# Epoch 39/40
# 240/240 - 6s - loss: 1.0978 - accuracy: 0.3318
# Epoch 40/40
# 240/240 - 6s - loss: 1.0990 - accuracy: 0.3485
# 65/65 - 2s - loss: 1.0802 - accuracy: 0.3868
# Epoch 1/40
# 246/246 - 7s - loss: 722.7939 - accuracy: 0.3781
# Epoch 2/40
# 246/246 - 6s - loss: 27.7594 - accuracy: 0.3725
# Epoch 3/40
# 246/246 - 6s - loss: 6.1677 - accuracy: 0.3679
# Epoch 4/40
# 246/246 - 6s - loss: 2.5728 - accuracy: 0.3496
# Epoch 5/40
# 246/246 - 6s - loss: 3.5864 - accuracy: 0.3573
# Epoch 6/40
# 246/246 - 6s - loss: 2.9157 - accuracy: 0.3659
# Epoch 7/40
# 246/246 - 6s - loss: 1.0935 - accuracy: 0.3491
# Epoch 8/40
# 246/246 - 6s - loss: 5.0511 - accuracy: 0.3547
# Epoch 9/40
# 246/246 - 6s - loss: 3.2506 - accuracy: 0.3578
# Epoch 10/40
# 246/246 - 6s - loss: 8.1312 - accuracy: 0.3481
# Epoch 11/40
# 246/246 - 6s - loss: 1.8890 - accuracy: 0.3623
# Epoch 12/40
# 246/246 - 6s - loss: 2.2732 - accuracy: 0.3522
# Epoch 13/40
# 246/246 - 6s - loss: 2.8287 - accuracy: 0.3664
# Epoch 14/40
# 246/246 - 6s - loss: 1.0926 - accuracy: 0.3669
# Epoch 15/40
# 246/246 - 6s - loss: 4.7995 - accuracy: 0.3659
# Epoch 16/40
# 246/246 - 6s - loss: 1.0908 - accuracy: 0.3679
# Epoch 17/40
# 246/246 - 6s - loss: 1.0894 - accuracy: 0.3883
# Epoch 18/40
# 246/246 - 6s - loss: 1.0920 - accuracy: 0.3649
# Epoch 19/40
# 246/246 - 6s - loss: 1.7320 - accuracy: 0.3735
# Epoch 20/40
# 246/246 - 6s - loss: 2.5085 - accuracy: 0.3634
# Epoch 21/40
# 246/246 - 6s - loss: 1.5495 - accuracy: 0.3613
# Epoch 22/40
# 246/246 - 6s - loss: 1.3909 - accuracy: 0.3628
# Epoch 23/40
# 246/246 - 6s - loss: 1.0926 - accuracy: 0.3659
# Epoch 24/40
# 246/246 - 6s - loss: 1.2486 - accuracy: 0.3649
# Epoch 25/40
# 246/246 - 6s - loss: 1.2623 - accuracy: 0.3690
# Epoch 26/40
# 246/246 - 6s - loss: 1.0936 - accuracy: 0.3578
# Epoch 27/40
# 246/246 - 6s - loss: 1.0916 - accuracy: 0.3730
# Epoch 28/40
# 246/246 - 6s - loss: 1.4643 - accuracy: 0.3603
# Epoch 29/40
# 246/246 - 6s - loss: 1.0928 - accuracy: 0.3608
# Epoch 30/40
# 246/246 - 6s - loss: 1.0925 - accuracy: 0.3654
# Epoch 31/40
# 246/246 - 6s - loss: 4.1121 - accuracy: 0.3481
# Epoch 32/40
# 246/246 - 6s - loss: 1.0936 - accuracy: 0.3517
# Epoch 33/40
# 246/246 - 6s - loss: 1.0931 - accuracy: 0.3618
# Epoch 34/40
# 246/246 - 6s - loss: 1.1185 - accuracy: 0.3567
# Epoch 35/40
# 246/246 - 6s - loss: 1.0935 - accuracy: 0.3583
# Epoch 36/40
# 246/246 - 6s - loss: 1.7463 - accuracy: 0.3730
# Epoch 37/40
# 246/246 - 6s - loss: 1.0929 - accuracy: 0.3700
# Epoch 38/40
# 246/246 - 6s - loss: 1.0929 - accuracy: 0.3674
# Epoch 39/40
# 246/246 - 6s - loss: 1.0930 - accuracy: 0.3578
# Epoch 40/40
# 246/246 - 6s - loss: 1.0952 - accuracy: 0.3628
# 59/59 - 2s - loss: 1.0993 - accuracy: 0.3004
# Epoch 1/40
# 243/243 - 7s - loss: 1225.3217 - accuracy: 0.5196
# Epoch 2/40
# 243/243 - 6s - loss: 65.4650 - accuracy: 0.3847
# Epoch 3/40
# 243/243 - 6s - loss: 18.1624 - accuracy: 0.3841
# Epoch 4/40
# 243/243 - 6s - loss: 4.3622 - accuracy: 0.3754
# Epoch 5/40
# 243/243 - 6s - loss: 2.2572 - accuracy: 0.3805
# Epoch 6/40
# 243/243 - 6s - loss: 1.3062 - accuracy: 0.3718
# Epoch 7/40
# 243/243 - 6s - loss: 1.1505 - accuracy: 0.3785
# Epoch 8/40
# 243/243 - 6s - loss: 7.2854 - accuracy: 0.3749
# Epoch 9/40
# 243/243 - 6s - loss: 1.5803 - accuracy: 0.3671
# Epoch 10/40
# 243/243 - 6s - loss: 1.3469 - accuracy: 0.3785
# Epoch 11/40
# 243/243 - 6s - loss: 3.6685 - accuracy: 0.3677
# Epoch 12/40
# 243/243 - 6s - loss: 1.9414 - accuracy: 0.3821
# Epoch 13/40
# 243/243 - 6s - loss: 1.0890 - accuracy: 0.3800
# Epoch 14/40
# 243/243 - 6s - loss: 2.8893 - accuracy: 0.3826
# Epoch 15/40
# 243/243 - 6s - loss: 1.0877 - accuracy: 0.3744
# Epoch 16/40
# 243/243 - 6s - loss: 1.0894 - accuracy: 0.3738
# Epoch 17/40
# 243/243 - 6s - loss: 1.2695 - accuracy: 0.3764
# Epoch 18/40
# 243/243 - 6s - loss: 1.0910 - accuracy: 0.3661
# Epoch 19/40
# 243/243 - 6s - loss: 1.3958 - accuracy: 0.3826
# Epoch 20/40
# 243/243 - 6s - loss: 2.6369 - accuracy: 0.3836
# Epoch 21/40
# 243/243 - 6s - loss: 2.2825 - accuracy: 0.3764
# Epoch 22/40
# 243/243 - 6s - loss: 1.9839 - accuracy: 0.3728
# Epoch 23/40
# 243/243 - 6s - loss: 1.0884 - accuracy: 0.3790
# Epoch 24/40
# 243/243 - 6s - loss: 15.7818 - accuracy: 0.3790
# Epoch 25/40
# 243/243 - 6s - loss: 1.0891 - accuracy: 0.3821
# Epoch 26/40
# 243/243 - 6s - loss: 2.7419 - accuracy: 0.3867
# Epoch 27/40
# 243/243 - 6s - loss: 12.4434 - accuracy: 0.3733
# Epoch 28/40
# 243/243 - 6s - loss: 2.0629 - accuracy: 0.3816
# Epoch 29/40
# 243/243 - 6s - loss: 1.0879 - accuracy: 0.3816
# Epoch 30/40
# 243/243 - 6s - loss: 4.8201 - accuracy: 0.3615
# Epoch 31/40
# 243/243 - 6s - loss: 1.0880 - accuracy: 0.3805
# Epoch 32/40
# 243/243 - 6s - loss: 1.0884 - accuracy: 0.3857
# Epoch 33/40
# 243/243 - 6s - loss: 1.1766 - accuracy: 0.3702
# Epoch 34/40
# 243/243 - 6s - loss: 2.0332 - accuracy: 0.3749
# Epoch 35/40
# 243/243 - 6s - loss: 1.5207 - accuracy: 0.3728
# Epoch 36/40
# 243/243 - 6s - loss: 1.1217 - accuracy: 0.3661
# Epoch 37/40
# 243/243 - 6s - loss: 1.0905 - accuracy: 0.3723
# Epoch 38/40
# 243/243 - 6s - loss: 1.0892 - accuracy: 0.3795
# Epoch 39/40
# 243/243 - 6s - loss: 4.3999 - accuracy: 0.3893
# Epoch 40/40
# 243/243 - 6s - loss: 1.0905 - accuracy: 0.3723
# 62/62 - 2s - loss: 1.1517 - accuracy: 0.2454
# Epoch 1/40
# 243/243 - 7s - loss: 789.6687 - accuracy: 0.4011
# Epoch 2/40
# 243/243 - 6s - loss: 20.4238 - accuracy: 0.3805
# Epoch 3/40
# 243/243 - 6s - loss: 9.4967 - accuracy: 0.3630
# Epoch 4/40
# 243/243 - 6s - loss: 6.9938 - accuracy: 0.3733
# Epoch 5/40
# 243/243 - 6s - loss: 8.4724 - accuracy: 0.3728
# Epoch 6/40
# 243/243 - 6s - loss: 16.5650 - accuracy: 0.3635
# Epoch 7/40
# 243/243 - 6s - loss: 1.3429 - accuracy: 0.3471
# Epoch 8/40
# 243/243 - 6s - loss: 1.9726 - accuracy: 0.3656
# Epoch 9/40
# 243/243 - 6s - loss: 1.2495 - accuracy: 0.3666
# Epoch 10/40
# 243/243 - 6s - loss: 1.8579 - accuracy: 0.3682
# Epoch 11/40
# 243/243 - 6s - loss: 5.6420 - accuracy: 0.3713
# Epoch 12/40
# 243/243 - 6s - loss: 3.2034 - accuracy: 0.3553
# Epoch 13/40
# 243/243 - 6s - loss: 2.3324 - accuracy: 0.3605
# Epoch 14/40
# 243/243 - 6s - loss: 8.9752 - accuracy: 0.3512
# Epoch 15/40
# 243/243 - 6s - loss: 10.3390 - accuracy: 0.3708
# Epoch 16/40
# 243/243 - 6s - loss: 7.5151 - accuracy: 0.3687
# Epoch 17/40
# 243/243 - 6s - loss: 1.0860 - accuracy: 0.3671
# Epoch 18/40
# 243/243 - 6s - loss: 2.3341 - accuracy: 0.3496
# Epoch 19/40
# 243/243 - 6s - loss: 1.0852 - accuracy: 0.3702
# Epoch 20/40
# 243/243 - 6s - loss: 1.0856 - accuracy: 0.3641
# Epoch 21/40
# 243/243 - 6s - loss: 1.2592 - accuracy: 0.3635
# Epoch 22/40
# 243/243 - 6s - loss: 1.0845 - accuracy: 0.3883
# Epoch 23/40
# 243/243 - 6s - loss: 1.1181 - accuracy: 0.3764
# Epoch 24/40
# 243/243 - 6s - loss: 1.0853 - accuracy: 0.3563
# Epoch 25/40
# 243/243 - 6s - loss: 1.0882 - accuracy: 0.3718
# Epoch 26/40
# 243/243 - 6s - loss: 1.0849 - accuracy: 0.3692
# Epoch 27/40
# 243/243 - 6s - loss: 1.2830 - accuracy: 0.3605
# Epoch 28/40
# 243/243 - 6s - loss: 1.0878 - accuracy: 0.3589
# Epoch 29/40
# 243/243 - 6s - loss: 1.0860 - accuracy: 0.3821
# Epoch 30/40
# 243/243 - 6s - loss: 1.0891 - accuracy: 0.3527
# Epoch 31/40
# 243/243 - 6s - loss: 1.0866 - accuracy: 0.3692
# Epoch 32/40
# 243/243 - 6s - loss: 1.0866 - accuracy: 0.3718
# Epoch 33/40
# 243/243 - 6s - loss: 2.2356 - accuracy: 0.3811
# Epoch 34/40
# 243/243 - 6s - loss: 1.0865 - accuracy: 0.3713
# Epoch 35/40
# 243/243 - 6s - loss: 1.0861 - accuracy: 0.3785
# Epoch 36/40
# 243/243 - 6s - loss: 1.0868 - accuracy: 0.3759
# Epoch 37/40
# 243/243 - 6s - loss: 1.0834 - accuracy: 0.3872
# Epoch 38/40
# 243/243 - 6s - loss: 1.0885 - accuracy: 0.3692
# Epoch 39/40
# 243/243 - 6s - loss: 2.3520 - accuracy: 0.3795
# Epoch 40/40
# 243/243 - 6s - loss: 1.0865 - accuracy: 0.3687
# 62/62 - 2s - loss: 1.1402 - accuracy: 0.3272
# Epoch 1/40
# 246/246 - 7s - loss: 945.0819 - accuracy: 0.3789
# Epoch 2/40
# 246/246 - 6s - loss: 36.0534 - accuracy: 0.3763
# Epoch 3/40
# 246/246 - 6s - loss: 11.6053 - accuracy: 0.3748
# Epoch 4/40
# 246/246 - 6s - loss: 8.5149 - accuracy: 0.3774
# Epoch 5/40
# 246/246 - 6s - loss: 10.9799 - accuracy: 0.3707
# Epoch 6/40
# 246/246 - 6s - loss: 1.8459 - accuracy: 0.3672
# Epoch 7/40
# 246/246 - 6s - loss: 1.9461 - accuracy: 0.3712
# Epoch 8/40
# 246/246 - 6s - loss: 3.2143 - accuracy: 0.3666
# Epoch 9/40
# 246/246 - 6s - loss: 2.0992 - accuracy: 0.3768
# Epoch 10/40
# 246/246 - 6s - loss: 1.1339 - accuracy: 0.3702
# Epoch 11/40
# 246/246 - 6s - loss: 1.5853 - accuracy: 0.3779
# Epoch 12/40
# 246/246 - 6s - loss: 2.8397 - accuracy: 0.3789
# Epoch 13/40
# 246/246 - 6s - loss: 1.2255 - accuracy: 0.3605
# Epoch 14/40
# 246/246 - 6s - loss: 1.0967 - accuracy: 0.3672
# Epoch 15/40
# 246/246 - 6s - loss: 1.5720 - accuracy: 0.3697
# Epoch 16/40
# 246/246 - 6s - loss: 1.3136 - accuracy: 0.3616
# Epoch 17/40
# 246/246 - 6s - loss: 1.0967 - accuracy: 0.3779
# Epoch 18/40
# 246/246 - 6s - loss: 6.6199 - accuracy: 0.3692
# Epoch 19/40
# 246/246 - 6s - loss: 1.6288 - accuracy: 0.3707
# Epoch 20/40
# 246/246 - 6s - loss: 1.0975 - accuracy: 0.3774
# Epoch 21/40
# 246/246 - 6s - loss: 1.0965 - accuracy: 0.3702
# Epoch 22/40
# 246/246 - 6s - loss: 1.7674 - accuracy: 0.3707
# Epoch 23/40
# 246/246 - 6s - loss: 1.6750 - accuracy: 0.3768
# Epoch 24/40
# 246/246 - 6s - loss: 2.0672 - accuracy: 0.3768
# Epoch 25/40
# 246/246 - 6s - loss: 2.1347 - accuracy: 0.3768
# Epoch 26/40
# 246/246 - 6s - loss: 2.3764 - accuracy: 0.3774
# Epoch 27/40
# 246/246 - 6s - loss: 1.3974 - accuracy: 0.3508
# Epoch 28/40
# 246/246 - 6s - loss: 1.0958 - accuracy: 0.3774
# Epoch 29/40
# 246/246 - 6s - loss: 3.1540 - accuracy: 0.3666
# Epoch 30/40
# 246/246 - 6s - loss: 1.3559 - accuracy: 0.3717
# Epoch 31/40
# 246/246 - 6s - loss: 1.0974 - accuracy: 0.3636
# Epoch 32/40
# 246/246 - 6s - loss: 1.1001 - accuracy: 0.3590
# Epoch 33/40
# 246/246 - 6s - loss: 1.0972 - accuracy: 0.3774
# Epoch 34/40
# 246/246 - 6s - loss: 1.0977 - accuracy: 0.3656
# Epoch 35/40
# 246/246 - 6s - loss: 2.3378 - accuracy: 0.3717
# Epoch 36/40
# 246/246 - 6s - loss: 1.0970 - accuracy: 0.3779
# Epoch 37/40
# 246/246 - 6s - loss: 1.0958 - accuracy: 0.3779
# Epoch 38/40
# 246/246 - 6s - loss: 5.4594 - accuracy: 0.3774
# Epoch 39/40
# 246/246 - 6s - loss: 1.0971 - accuracy: 0.3774
# Epoch 40/40
# 246/246 - 6s - loss: 1.0966 - accuracy: 0.3712
# 59/59 - 2s - loss: 1.1540 - accuracy: 0.2979
# Epoch 1/20
# 120/120 - 6s - loss: 49.9457 - accuracy: 0.5805
# Epoch 2/20
# 120/120 - 4s - loss: 12.4250 - accuracy: 0.8365
# Epoch 3/20
# 120/120 - 4s - loss: 6.0910 - accuracy: 0.9133
# Epoch 4/20
# 120/120 - 4s - loss: 2.5285 - accuracy: 0.9566
# Epoch 5/20
# 120/120 - 4s - loss: 2.5207 - accuracy: 0.9650
# Epoch 6/20
# 120/120 - 4s - loss: 1.3238 - accuracy: 0.9754
# Epoch 7/20
# 120/120 - 4s - loss: 0.8096 - accuracy: 0.9848
# Epoch 8/20
# 120/120 - 4s - loss: 0.5856 - accuracy: 0.9869
# Epoch 9/20
# 120/120 - 4s - loss: 0.5709 - accuracy: 0.9901
# Epoch 10/20
# 120/120 - 4s - loss: 0.4321 - accuracy: 0.9906
# Epoch 11/20
# 120/120 - 4s - loss: 0.0799 - accuracy: 0.9969
# Epoch 12/20
# 120/120 - 4s - loss: 0.1612 - accuracy: 0.9953
# Epoch 13/20
# 120/120 - 4s - loss: 0.3167 - accuracy: 0.9943
# Epoch 14/20
# 120/120 - 4s - loss: 0.0692 - accuracy: 0.9969
# Epoch 15/20
# 120/120 - 4s - loss: 0.0881 - accuracy: 0.9958
# Epoch 16/20
# 120/120 - 4s - loss: 0.1403 - accuracy: 0.9974
# Epoch 17/20
# 120/120 - 4s - loss: 0.1317 - accuracy: 0.9969
# Epoch 18/20
# 120/120 - 4s - loss: 0.0563 - accuracy: 0.9984
# Epoch 19/20
# 120/120 - 4s - loss: 0.0878 - accuracy: 0.9974
# Epoch 20/20
# 120/120 - 4s - loss: 0.0717 - accuracy: 0.9984
# 33/33 - 1s - loss: 13.1442 - accuracy: 0.8839
# Epoch 1/20
# 123/123 - 6s - loss: 51.9823 - accuracy: 0.5517
# Epoch 2/20
# 123/123 - 4s - loss: 12.7607 - accuracy: 0.8305
# Epoch 3/20
# 123/123 - 4s - loss: 6.9208 - accuracy: 0.9043
# Epoch 4/20
# 123/123 - 4s - loss: 3.7334 - accuracy: 0.9476
# Epoch 5/20
# 123/123 - 4s - loss: 2.7369 - accuracy: 0.9649
# Epoch 6/20
# Epoch 18/20
# 123/123 - 4s - loss: 0.3544 - accuracy: 0.9964
# Epoch 19/20
# 123/123 - 4s - loss: 0.2923 - accuracy: 0.9980
# Epoch 20/20
# 123/123 - 4s - loss: 0.0502 - accuracy: 0.9985
# 30/30 - 1s - loss: 17.1717 - accuracy: 0.8426
# Epoch 1/10
# 60/60 - 10s - loss: 14.1447 - accuracy: 0.4441
# Epoch 2/10
# 60/60 - 4s - loss: 4.2135 - accuracy: 0.6823
# Epoch 3/10
# 60/60 - 4s - loss: 1.3511 - accuracy: 0.8135
# Epoch 4/10
# 60/60 - 4s - loss: 0.6930 - accuracy: 0.8866
# Epoch 5/10
# 60/60 - 4s - loss: 0.3895 - accuracy: 0.9305
# Epoch 6/10
# 60/60 - 4s - loss: 0.2422 - accuracy: 0.9457
# Epoch 7/10
# 60/60 - 4s - loss: 0.2018 - accuracy: 0.9566
# Epoch 8/10
# 60/60 - 4s - loss: 0.1571 - accuracy: 0.9624
# Epoch 9/10
# 60/60 - 4s - loss: 0.1292 - accuracy: 0.9707
# Epoch 10/10
# 60/60 - 4s - loss: 0.0950 - accuracy: 0.9692
# 17/17 - 1s - loss: 0.9204 - accuracy: 0.8201
# Epoch 1/10
# 62/62 - 5s - loss: 14.5876 - accuracy: 0.4249
# Epoch 2/10
# 62/62 - 4s - loss: 4.2647 - accuracy: 0.5883
# Epoch 3/10
# 62/62 - 4s - loss: 1.4025 - accuracy: 0.7181
# Epoch 4/10
# 62/62 - 4s - loss: 0.7681 - accuracy: 0.8178
# Epoch 5/10
# 62/62 - 4s - loss: 0.4956 - accuracy: 0.8601
# Epoch 6/10
# 62/62 - 4s - loss: 0.3959 - accuracy: 0.8819
# Epoch 7/10
# 62/62 - 4s - loss: 0.2969 - accuracy: 0.9221
# Epoch 8/10
# 62/62 - 4s - loss: 0.2392 - accuracy: 0.9257
# Epoch 9/10
# 62/62 - 4s - loss: 0.2013 - accuracy: 0.9405
# Epoch 10/10
# 62/62 - 4s - loss: 0.1839 - accuracy: 0.9481
# 15/15 - 3s - loss: 0.3923 - accuracy: 0.8991
# Epoch 1/10
# 61/61 - 7s - loss: 12.1684 - accuracy: 0.4598
# Epoch 2/10
# 61/61 - 4s - loss: 3.4878 - accuracy: 0.6818
# Epoch 3/10
# 61/61 - 4s - loss: 1.4208 - accuracy: 0.7884
# Epoch 4/10
# 61/61 - 4s - loss: 0.5768 - accuracy: 0.8785
# Epoch 5/10
# 61/61 - 4s - loss: 0.4750 - accuracy: 0.9063
# Epoch 6/10
# 61/61 - 4s - loss: 0.2844 - accuracy: 0.9408
# Epoch 7/10
# 61/61 - 4s - loss: 0.2316 - accuracy: 0.9578
# Epoch 8/10
# 61/61 - 4s - loss: 0.2174 - accuracy: 0.9567
# Epoch 9/10
# 61/61 - 4s - loss: 0.1209 - accuracy: 0.9691
# Epoch 10/10
# 61/61 - 4s - loss: 0.1356 - accuracy: 0.9691
# 16/16 - 1s - loss: 2.1470 - accuracy: 0.6789
# Epoch 1/10
# 61/61 - 5s - loss: 14.1552 - accuracy: 0.4583
# Epoch 2/10
# 61/61 - 4s - loss: 4.0665 - accuracy: 0.6807
# Epoch 3/10
# 61/61 - 4s - loss: 1.2842 - accuracy: 0.8383
# Epoch 4/10
# 61/61 - 4s - loss: 0.4519 - accuracy: 0.9089
# Epoch 5/10
# 61/61 - 4s - loss: 0.3654 - accuracy: 0.9372
# Epoch 6/10
# 61/61 - 4s - loss: 0.2999 - accuracy: 0.9439
# Epoch 7/10
# 61/61 - 4s - loss: 0.2811 - accuracy: 0.9470
# Epoch 8/10
# 61/61 - 4s - loss: 0.1392 - accuracy: 0.9645
# Epoch 9/10
# 61/61 - 4s - loss: 0.1025 - accuracy: 0.9779
# Epoch 10/10
# 61/61 - 4s - loss: 0.1082 - accuracy: 0.9758
# 16/16 - 1s - loss: 3.1136 - accuracy: 0.7955
# Epoch 1/10
# 62/62 - 5s - loss: 13.9400 - accuracy: 0.4396
# Epoch 2/10
# 62/62 - 4s - loss: 3.6953 - accuracy: 0.6604
# Epoch 3/10
# 62/62 - 4s - loss: 1.3138 - accuracy: 0.7675
# Epoch 4/10
# 62/62 - 4s - loss: 0.8838 - accuracy: 0.8123
# Epoch 5/10
# 62/62 - 4s - loss: 0.5377 - accuracy: 0.8771
# Epoch 6/10
# 62/62 - 4s - loss: 0.3476 - accuracy: 0.9021
# Epoch 7/10
# 62/62 - 4s - loss: 0.2949 - accuracy: 0.9118
# Epoch 8/10
# 62/62 - 4s - loss: 0.2494 - accuracy: 0.9312
# Epoch 9/10
# 62/62 - 4s - loss: 0.2270 - accuracy: 0.9363
# Epoch 10/10
# 62/62 - 4s - loss: 0.2023 - accuracy: 0.9398
# 15/15 - 1s - loss: 0.6913 - accuracy: 0.8447
# Epoch 1/20
# 120/120 - 5s - loss: 1226.5338 - accuracy: 0.5569
# Epoch 2/20
# 120/120 - 4s - loss: 110.4937 - accuracy: 0.3882
# Epoch 3/20
# 120/120 - 4s - loss: 15.4190 - accuracy: 0.3480
# Epoch 4/20
# 120/120 - 4s - loss: 7.7918 - accuracy: 0.3527
# Epoch 5/20
# 120/120 - 4s - loss: 3.8075 - accuracy: 0.3286
# Epoch 6/20
# 120/120 - 4s - loss: 6.8052 - accuracy: 0.3480
# Epoch 7/20
# 120/120 - 4s - loss: 9.9361 - accuracy: 0.3589
# Epoch 8/20
# 120/120 - 4s - loss: 2.9454 - accuracy: 0.3490
# Epoch 9/20
# 120/120 - 4s - loss: 3.3384 - accuracy: 0.3506
# Epoch 10/20
# 120/120 - 4s - loss: 5.2016 - accuracy: 0.3401
# Epoch 11/20
# 120/120 - 4s - loss: 6.7640 - accuracy: 0.3344
# Epoch 12/20
# 120/120 - 4s - loss: 8.1930 - accuracy: 0.3443
# Epoch 13/20
# 120/120 - 4s - loss: 6.2506 - accuracy: 0.3454
# Epoch 14/20
# 120/120 - 4s - loss: 1.4984 - accuracy: 0.3370
# Epoch 15/20
# 120/120 - 4s - loss: 2.8267 - accuracy: 0.3532
# Epoch 16/20
# 120/120 - 4s - loss: 1.5148 - accuracy: 0.3506
# Epoch 17/20
# Epoch 8/20
# 123/123 - 4s - loss: 3.0494 - accuracy: 0.3753
# Epoch 9/20
# 123/123 - 4s - loss: 2.0803 - accuracy: 0.3774
# Epoch 10/20
# 123/123 - 4s - loss: 3.2550 - accuracy: 0.3768
# Epoch 11/20
# 123/123 - 4s - loss: 1.0957 - accuracy: 0.3779
# Epoch 12/20
# 123/123 - 4s - loss: 1.4317 - accuracy: 0.3779
# Epoch 13/20
# 123/123 - 4s - loss: 1.1582 - accuracy: 0.3768
# Epoch 14/20
# 123/123 - 4s - loss: 1.3237 - accuracy: 0.3646
# Epoch 15/20
# 123/123 - 4s - loss: 2.0552 - accuracy: 0.3779
# Epoch 16/20
# 123/123 - 4s - loss: 1.7670 - accuracy: 0.3774
# Epoch 17/20
# 123/123 - 4s - loss: 1.0962 - accuracy: 0.3774
# Epoch 18/20
# 123/123 - 4s - loss: 1.0956 - accuracy: 0.3779
# Epoch 19/20
# 123/123 - 4s - loss: 1.0954 - accuracy: 0.3774
# Epoch 20/20
# 123/123 - 4s - loss: 3.5147 - accuracy: 0.3768
# 30/30 - 1s - loss: 1.0801 - accuracy: 0.2979
# Epoch 1/40
# 240/240 - 6s - loss: 44.7355 - accuracy: 0.5554
# Epoch 2/40
# 240/240 - 6s - loss: 9.1664 - accuracy: 0.8678
# Epoch 3/40
# 240/240 - 6s - loss: 3.2697 - accuracy: 0.9556
# Epoch 4/40
# 240/240 - 6s - loss: 1.6044 - accuracy: 0.9692
# Epoch 5/40
# 240/240 - 6s - loss: 1.1762 - accuracy: 0.9854
# Epoch 6/40
# 240/240 - 6s - loss: 1.1758 - accuracy: 0.9854
# Epoch 7/40
# 240/240 - 6s - loss: 0.9416 - accuracy: 0.9890
# Epoch 8/40
# 240/240 - 6s - loss: 0.3170 - accuracy: 0.9916
# Epoch 9/40
# 240/240 - 6s - loss: 0.8442 - accuracy: 0.9885
# Epoch 10/40
# 240/240 - 6s - loss: 1.0398 - accuracy: 0.9880
# Epoch 11/40
# 240/240 - 6s - loss: 0.6948 - accuracy: 0.9932
# Epoch 12/40
# 240/240 - 6s - loss: 1.6344 - accuracy: 0.9916
# Epoch 13/40
# 240/240 - 6s - loss: 4.0835 - accuracy: 0.9807
# Epoch 14/40
# 240/240 - 6s - loss: 2.9927 - accuracy: 0.9822
# Epoch 15/40
# 240/240 - 6s - loss: 4.1967 - accuracy: 0.9880
# Epoch 16/40
# 240/240 - 6s - loss: 5.2691 - accuracy: 0.9901
# Epoch 17/40
# 240/240 - 6s - loss: 5.9700 - accuracy: 0.9901
# Epoch 18/40
# 240/240 - 6s - loss: 0.5144 - accuracy: 0.9969
# Epoch 19/40
# 240/240 - 6s - loss: 0.7630 - accuracy: 0.9963
# Epoch 20/40
# 240/240 - 6s - loss: 1.5231 - accuracy: 0.9979
# Epoch 21/40
# 240/240 - 6s - loss: 2.7318 - accuracy: 0.9953
# Epoch 22/40
# 240/240 - 6s - loss: 1.5112 - accuracy: 0.9958
# Epoch 23/40
# 240/240 - 6s - loss: 0.2748 - accuracy: 0.9974
# Epoch 24/40
# 240/240 - 6s - loss: 0.1854 - accuracy: 0.9979
# Epoch 25/40
# 240/240 - 6s - loss: 0.7836 - accuracy: 0.9974
# Epoch 26/40
# 240/240 - 6s - loss: 1.0969 - accuracy: 0.9969
# Epoch 27/40
# 240/240 - 6s - loss: 0.8899 - accuracy: 0.9974
# Epoch 28/40
# 240/240 - 6s - loss: 0.5811 - accuracy: 0.9974
# Epoch 29/40
# 240/240 - 6s - loss: 4.3659 - accuracy: 0.9958
# Epoch 30/40
# 240/240 - 6s - loss: 4.9671 - accuracy: 0.9890
# Epoch 31/40
# 240/240 - 6s - loss: 4.5507 - accuracy: 0.9927
# Epoch 32/40
# 240/240 - 6s - loss: 6.9435 - accuracy: 0.9958
# Epoch 33/40
# 240/240 - 6s - loss: 0.2624 - accuracy: 0.9969
# Epoch 34/40
# 240/240 - 6s - loss: 0.6097 - accuracy: 0.9979
# Epoch 35/40
# 240/240 - 6s - loss: 0.0475 - accuracy: 0.9990
# Epoch 36/40
# 240/240 - 6s - loss: 0.7629 - accuracy: 0.9979
# Epoch 37/40
# 240/240 - 6s - loss: 0.7571 - accuracy: 0.9984
# Epoch 38/40
# 240/240 - 6s - loss: 0.4471 - accuracy: 0.9990
# Epoch 39/40
# 240/240 - 6s - loss: 0.4432 - accuracy: 0.9984
# Epoch 40/40
# 240/240 - 6s - loss: 1.7059 - accuracy: 0.9958
# 65/65 - 2s - loss: 111.1951 - accuracy: 0.8917
# Epoch 1/40
# 246/246 - 7s - loss: 46.2471 - accuracy: 0.5415
# Epoch 2/40
# 246/246 - 6s - loss: 9.6781 - accuracy: 0.8382
# Epoch 3/40
# 246/246 - 6s - loss: 4.1173 - accuracy: 0.9288
# Epoch 4/40
# 246/246 - 6s - loss: 1.9433 - accuracy: 0.9578
# Epoch 5/40
# 246/246 - 6s - loss: 0.6833 - accuracy: 0.9822
# Epoch 6/40
# 246/246 - 6s - loss: 0.4829 - accuracy: 0.9847
# Epoch 7/40
# 246/246 - 6s - loss: 0.1999 - accuracy: 0.9939
# Epoch 8/40
# 246/246 - 6s - loss: 1.0797 - accuracy: 0.9868
# Epoch 9/40
# 246/246 - 6s - loss: 0.6602 - accuracy: 0.9893
# Epoch 10/40
# 246/246 - 6s - loss: 1.2412 - accuracy: 0.9827
# Epoch 11/40
# 246/246 - 6s - loss: 0.8057 - accuracy: 0.9868
# Epoch 12/40
# 246/246 - 6s - loss: 1.2999 - accuracy: 0.9858
# Epoch 13/40
# 246/246 - 6s - loss: 1.5552 - accuracy: 0.9868
# Epoch 14/40
# 246/246 - 6s - loss: 1.0882 - accuracy: 0.9924
# Epoch 15/40
# 246/246 - 6s - loss: 0.3491 - accuracy: 0.9975
# Epoch 16/40
# 246/246 - 6s - loss: 1.1140 - accuracy: 0.9939
# Epoch 17/40
# 246/246 - 6s - loss: 0.5502 - accuracy: 0.9944
# Epoch 18/40
# 246/246 - 6s - loss: 0.8629 - accuracy: 0.9944
# Epoch 19/40
# 246/246 - 6s - loss: 2.6891 - accuracy: 0.9827
# Epoch 20/40
# 246/246 - 6s - loss: 1.8658 - accuracy: 0.9842
# Epoch 21/40
# 246/246 - 6s - loss: 1.0387 - accuracy: 0.9954
# Epoch 22/40
# 246/246 - 6s - loss: 1.3938 - accuracy: 0.9913
# Epoch 23/40
# 246/246 - 6s - loss: 1.1340 - accuracy: 0.9924
# Epoch 24/40
# 246/246 - 6s - loss: 1.9867 - accuracy: 0.9913
# Epoch 25/40
# 246/246 - 6s - loss: 0.5088 - accuracy: 0.9949
# Epoch 26/40
# 246/246 - 6s - loss: 0.9567 - accuracy: 0.9944
# Epoch 27/40
# 246/246 - 6s - loss: 1.4938 - accuracy: 0.9929
# Epoch 28/40
# 246/246 - 6s - loss: 0.4505 - accuracy: 0.9975
# Epoch 29/40
# 246/246 - 6s - loss: 0.3793 - accuracy: 0.9964
# Epoch 30/40
# 246/246 - 6s - loss: 0.2200 - accuracy: 0.9980
# Epoch 31/40
# 246/246 - 6s - loss: 0.7535 - accuracy: 0.9959
# Epoch 32/40
# 246/246 - 6s - loss: 0.1872 - accuracy: 0.9980
# Epoch 33/40
# 246/246 - 6s - loss: 2.5014 - accuracy: 0.9934
# Epoch 34/40
# 246/246 - 6s - loss: 3.1002 - accuracy: 0.9908
# Epoch 35/40
# 246/246 - 6s - loss: 0.2230 - accuracy: 0.9980
# Epoch 36/40
# 246/246 - 6s - loss: 0.2033 - accuracy: 0.9990
# Epoch 37/40
# 246/246 - 6s - loss: 1.5198 - accuracy: 0.9969
# Epoch 38/40
# 246/246 - 6s - loss: 0.7214 - accuracy: 0.9980
# Epoch 39/40
# 246/246 - 6s - loss: 0.2111 - accuracy: 0.9985
# Epoch 40/40
# 246/246 - 6s - loss: 1.2044 - accuracy: 0.9980
# 59/59 - 2s - loss: 311.8160 - accuracy: 0.9056
# Epoch 1/40
# 243/243 - 7s - loss: 45.0126 - accuracy: 0.5510
# Epoch 2/40
# 243/243 - 6s - loss: 8.4903 - accuracy: 0.8527
# Epoch 3/40
# 243/243 - 6s - loss: 2.7419 - accuracy: 0.9511
# Epoch 4/40
# 243/243 - 6s - loss: 1.3700 - accuracy: 0.9696
# Epoch 5/40
# 243/243 - 6s - loss: 1.4980 - accuracy: 0.9789
# Epoch 6/40
# 243/243 - 6s - loss: 1.7975 - accuracy: 0.9820
# Epoch 7/40
# 243/243 - 6s - loss: 1.1002 - accuracy: 0.9887
# Epoch 8/40
# 243/243 - 6s - loss: 2.1376 - accuracy: 0.9856
# Epoch 9/40
# 243/243 - 6s - loss: 1.1602 - accuracy: 0.9887
# Epoch 10/40
# 243/243 - 6s - loss: 1.0210 - accuracy: 0.9887
# Epoch 11/40
# 243/243 - 6s - loss: 0.2856 - accuracy: 0.9959
# Epoch 12/40
# 243/243 - 6s - loss: 0.4989 - accuracy: 0.9954
# Epoch 13/40
# 243/243 - 6s - loss: 0.6614 - accuracy: 0.9969
# Epoch 14/40
# 243/243 - 6s - loss: 0.3265 - accuracy: 0.9959
# Epoch 15/40
# 243/243 - 6s - loss: 1.0642 - accuracy: 0.9933
# Epoch 16/40
# 243/243 - 6s - loss: 0.6122 - accuracy: 0.9943
# Epoch 17/40
# 243/243 - 6s - loss: 1.3252 - accuracy: 0.9902
# Epoch 18/40
# 243/243 - 6s - loss: 0.6456 - accuracy: 0.9959
# Epoch 19/40
# 243/243 - 6s - loss: 0.7492 - accuracy: 0.9928
# Epoch 20/40
# 243/243 - 6s - loss: 9.9464e-07 - accuracy: 1.0000
# Epoch 21/40
# 243/243 - 6s - loss: 1.9502 - accuracy: 0.9964
# Epoch 22/40
# 243/243 - 6s - loss: 1.1081 - accuracy: 0.9969
# Epoch 23/40
# 243/243 - 6s - loss: 0.9690 - accuracy: 0.9964
# Epoch 24/40
# 243/243 - 6s - loss: 1.1980 - accuracy: 0.9969
# Epoch 25/40
# 243/243 - 6s - loss: 6.9108 - accuracy: 0.9897
# Epoch 26/40
# 243/243 - 6s - loss: 5.6031 - accuracy: 0.9897
# Epoch 27/40
# 243/243 - 6s - loss: 1.2039 - accuracy: 0.9969
# Epoch 28/40
# 243/243 - 6s - loss: 3.5633 - accuracy: 0.9959
# Epoch 29/40
# 243/243 - 6s - loss: 2.8913 - accuracy: 0.9974
# Epoch 30/40
# 243/243 - 6s - loss: 0.8123 - accuracy: 0.9990
# Epoch 31/40
# 243/243 - 6s - loss: 0.3645 - accuracy: 0.9974
# Epoch 32/40
# 243/243 - 6s - loss: 1.6338 - accuracy: 0.9974
# Epoch 33/40
# 243/243 - 6s - loss: 0.2898 - accuracy: 0.9995
# Epoch 34/40
# 243/243 - 6s - loss: 0.2053 - accuracy: 0.9990
# Epoch 35/40
# 243/243 - 6s - loss: 0.3069 - accuracy: 0.9995
# Epoch 36/40
# 243/243 - 6s - loss: 3.1196 - accuracy: 0.9954
# Epoch 37/40
# 243/243 - 6s - loss: 2.0482 - accuracy: 0.9990
# Epoch 38/40
# 243/243 - 6s - loss: 0.2448 - accuracy: 0.9990
# Epoch 39/40
# 243/243 - 6s - loss: 1.0854 - accuracy: 0.9985
# Epoch 40/40
# 243/243 - 6s - loss: 2.5107 - accuracy: 0.9985
# 62/62 - 2s - loss: 1138.5341 - accuracy: 0.6585
# Epoch 1/40
# 243/243 - 7s - loss: 41.6287 - accuracy: 0.6277
# Epoch 2/40
# 243/243 - 6s - loss: 8.1247 - accuracy: 0.9130
# Epoch 3/40
# 243/243 - 6s - loss: 3.1058 - accuracy: 0.9614
# Epoch 4/40
# 243/243 - 6s - loss: 3.1487 - accuracy: 0.9748
# Epoch 5/40
# 243/243 - 6s - loss: 2.2861 - accuracy: 0.9815
# Epoch 6/40
# 243/243 - 6s - loss: 0.7582 - accuracy: 0.9928
# Epoch 7/40
# 243/243 - 6s - loss: 1.5282 - accuracy: 0.9907
# Epoch 8/40
# 243/243 - 6s - loss: 1.3380 - accuracy: 0.9897
# Epoch 9/40
# 243/243 - 6s - loss: 0.9830 - accuracy: 0.9912
# Epoch 10/40
# 243/243 - 6s - loss: 0.1583 - accuracy: 0.9974
# Epoch 11/40
# 243/243 - 6s - loss: 0.3065 - accuracy: 0.9964
# Epoch 12/40
# 243/243 - 6s - loss: 0.2254 - accuracy: 0.9985
# Epoch 13/40
# 243/243 - 6s - loss: 0.1308 - accuracy: 0.9974
# Epoch 14/40
# 243/243 - 6s - loss: 1.5674 - accuracy: 0.9923
# Epoch 15/40
# 243/243 - 6s - loss: 1.7983 - accuracy: 0.9928
# Epoch 16/40
# 243/243 - 6s - loss: 10.6946 - accuracy: 0.9789
# Epoch 17/40
# 243/243 - 6s - loss: 4.8427 - accuracy: 0.9887
# Epoch 18/40
# 243/243 - 6s - loss: 1.2324 - accuracy: 0.9949
# Epoch 19/40
# 243/243 - 6s - loss: 1.4918 - accuracy: 0.9954
# Epoch 20/40
# 243/243 - 6s - loss: 2.7145 - accuracy: 0.9959
# Epoch 21/40
# 243/243 - 6s - loss: 0.3011 - accuracy: 0.9995
# Epoch 22/40
# 243/243 - 6s - loss: 2.3349 - accuracy: 0.9969
# Epoch 23/40
# ...
# Epoch 17/20
# 243/243 - 6s - loss: 0.1576 - accuracy: 0.9974
# Epoch 18/20
# 243/243 - 6s - loss: 0.2881 - accuracy: 0.9954
# Epoch 19/20
# 243/243 - 6s - loss: 0.0951 - accuracy: 0.9979
# Epoch 20/20
# 243/243 - 6s - loss: 0.0147 - accuracy: 0.9974
# 62/62 - 2s - loss: 46.8308 - accuracy: 0.8303
# Epoch 1/20
# 246/246 - 7s - loss: 58.1583 - accuracy: 0.5467
# Epoch 2/20
# 246/246 - 6s - loss: 13.9815 - accuracy: 0.8174
# Epoch 3/20
# 246/246 - 6s - loss: 6.4856 - accuracy: 0.9189
# Epoch 4/20
# 246/246 - 6s - loss: 4.4483 - accuracy: 0.9403
# Epoch 5/20
# 246/246 - 6s - loss: 1.8854 - accuracy: 0.9653
# Epoch 6/20
# 246/246 - 6s - loss: 1.1904 - accuracy: 0.9791
# Epoch 7/20
# 246/246 - 6s - loss: 0.8908 - accuracy: 0.9852
# Epoch 8/20
# 246/246 - 6s - loss: 0.9416 - accuracy: 0.9862
# Epoch 9/20
# 246/246 - 6s - loss: 0.5525 - accuracy: 0.9893
# Epoch 10/20
# 246/246 - 6s - loss: 0.5274 - accuracy: 0.9883
# Epoch 11/20
# 246/246 - 6s - loss: 0.6435 - accuracy: 0.9918
# Epoch 12/20
# 246/246 - 6s - loss: 0.3178 - accuracy: 0.9959
# Epoch 13/20
# 246/246 - 6s - loss: 0.0731 - accuracy: 0.9959
# Epoch 14/20
# 246/246 - 6s - loss: 0.3370 - accuracy: 0.9944
# Epoch 15/20
# 246/246 - 6s - loss: 0.2347 - accuracy: 0.9969
# Epoch 16/20
# 246/246 - 6s - loss: 0.2914 - accuracy: 0.9949
# Epoch 17/20
# 246/246 - 6s - loss: 0.1593 - accuracy: 0.9969
# Epoch 18/20
# 246/246 - 6s - loss: 0.2388 - accuracy: 0.9964
# Epoch 19/20
# 246/246 - 6s - loss: 0.3214 - accuracy: 0.9949
# Epoch 20/20
# 246/246 - 6s - loss: 0.1008 - accuracy: 0.9959
# 59/59 - 2s - loss: 30.9493 - accuracy: 0.8511
# Epoch 1/20
# 240/240 - 7s - loss: 43.1975 - accuracy: 0.5857
# Epoch 2/20
# 240/240 - 6s - loss: 6.5033 - accuracy: 0.8762
# Epoch 3/20
# 240/240 - 6s - loss: 4.4073 - accuracy: 0.9326
# Epoch 4/20
# 240/240 - 6s - loss: 1.7877 - accuracy: 0.9639
# Epoch 5/20
# 240/240 - 6s - loss: 1.2777 - accuracy: 0.9791
# Epoch 6/20
# 240/240 - 6s - loss: 0.7654 - accuracy: 0.9828
# Epoch 7/20
# 240/240 - 6s - loss: 1.3552 - accuracy: 0.9786
# Epoch 8/20
# 240/240 - 6s - loss: 1.1196 - accuracy: 0.9869
# Epoch 9/20
# 240/240 - 6s - loss: 0.6176 - accuracy: 0.9916
# Epoch 10/20
# 240/240 - 6s - loss: 0.4777 - accuracy: 0.9922
# Epoch 11/20
# 240/240 - 6s - loss: 1.8416 - accuracy: 0.9869
# Epoch 12/20
# 240/240 - 6s - loss: 1.1235 - accuracy: 0.9916
# Epoch 13/20
# 240/240 - 6s - loss: 1.4143 - accuracy: 0.9922
# Epoch 14/20
# 240/240 - 6s - loss: 2.5129 - accuracy: 0.9880
# Epoch 15/20
# 240/240 - 6s - loss: 2.4011 - accuracy: 0.9854
# Epoch 16/20
# 240/240 - 6s - loss: 4.7032 - accuracy: 0.9885
# Epoch 17/20
# 240/240 - 6s - loss: 3.4563 - accuracy: 0.9916
# Epoch 18/20
# 240/240 - 6s - loss: 1.2626 - accuracy: 0.9916
# Epoch 19/20
# 240/240 - 6s - loss: 0.5738 - accuracy: 0.9958
# Epoch 20/20
# 240/240 - 6s - loss: 1.3702e-08 - accuracy: 1.0000
# 65/65 - 2s - loss: 36.7871 - accuracy: 0.8337
# Epoch 1/20
# 246/246 - 7s - loss: 41.5666 - accuracy: 0.5720
# Epoch 2/20
# 246/246 - 6s - loss: 10.4832 - accuracy: 0.8570
# Epoch 3/20
# 246/246 - 6s - loss: 3.9721 - accuracy: 0.9491
# Epoch 4/20
# 246/246 - 6s - loss: 1.6110 - accuracy: 0.9740
# Epoch 5/20
# 246/246 - 6s - loss: 1.4263 - accuracy: 0.9807
# Epoch 6/20
# 246/246 - 6s - loss: 0.6559 - accuracy: 0.9898
# Epoch 7/20
# 246/246 - 6s - loss: 0.3769 - accuracy: 0.9954
# Epoch 8/20
# 246/246 - 6s - loss: 1.0143 - accuracy: 0.9939
# Epoch 9/20
# 246/246 - 6s - loss: 1.1370 - accuracy: 0.9888
# Epoch 10/20
# 246/246 - 6s - loss: 0.8189 - accuracy: 0.9893
# Epoch 11/20
# 246/246 - 6s - loss: 0.6329 - accuracy: 0.9913
# Epoch 12/20
# 246/246 - 6s - loss: 1.2579 - accuracy: 0.9919
# Epoch 13/20
# 246/246 - 6s - loss: 0.5394 - accuracy: 0.9929
# Epoch 14/20
# 246/246 - 6s - loss: 0.2251 - accuracy: 0.9939
# Epoch 15/20
# 246/246 - 6s - loss: 1.1346 - accuracy: 0.9919
# Epoch 16/20
# 246/246 - 6s - loss: 5.2292 - accuracy: 0.9776
# Epoch 17/20
# 246/246 - 6s - loss: 4.3205 - accuracy: 0.9837
# Epoch 18/20
# 246/246 - 6s - loss: 1.2052 - accuracy: 0.9903
# Epoch 19/20
# 246/246 - 6s - loss: 2.3807 - accuracy: 0.9929
# Epoch 20/20
# 246/246 - 6s - loss: 0.5768 - accuracy: 0.9959
# 59/59 - 2s - loss: 261.1238 - accuracy: 0.9249
# Epoch 1/20
# 243/243 - 7s - loss: 40.0221 - accuracy: 0.5860
# Epoch 2/20
# 243/243 - 6s - loss: 5.8116 - accuracy: 0.8847
# Epoch 3/20
# 243/243 - 6s - loss: 1.7248 - accuracy: 0.9691
# Epoch 4/20
# 243/243 - 6s - loss: 1.6039 - accuracy: 0.9799
# Epoch 5/20
# 243/243 - 6s - loss: 1.2400 - accuracy: 0.9892
# Epoch 6/20
# 243/243 - 6s - loss: 0.7472 - accuracy: 0.9912
# Epoch 7/20
# 243/243 - 6s - loss: 0.4575 - accuracy: 0.9943
# Epoch 8/20
# 243/243 - 6s - loss: 0.2215 - accuracy: 0.9974
# Epoch 9/20
# 243/243 - 6s - loss: 1.1408 - accuracy: 0.9923
# Epoch 10/20
# 243/243 - 6s - loss: 0.8114 - accuracy: 0.9933
# Epoch 11/20
# 243/243 - 6s - loss: 3.1332 - accuracy: 0.9784
# Epoch 12/20
# 243/243 - 6s - loss: 6.4690 - accuracy: 0.9784
# Epoch 13/20
# 243/243 - 6s - loss: 1.8436 - accuracy: 0.9897
# Epoch 14/20
# 243/243 - 6s - loss: 3.0380 - accuracy: 0.9907
# Epoch 15/20
# 243/243 - 6s - loss: 0.0990 - accuracy: 0.9990
# Epoch 16/20
# 243/243 - 6s - loss: 0.5405 - accuracy: 0.9974
# Epoch 17/20
# 243/243 - 6s - loss: 1.3640 - accuracy: 0.9943
# Epoch 18/20
# 243/243 - 6s - loss: 1.1349 - accuracy: 0.9954
# Epoch 19/20
# 243/243 - 6s - loss: 0.6457 - accuracy: 0.9974
# Epoch 20/20
# 243/243 - 6s - loss: 1.2042 - accuracy: 0.9979
# 62/62 - 2s - loss: 477.2875 - accuracy: 0.6708
# Epoch 1/20
# 243/243 - 7s - loss: 43.9836 - accuracy: 0.5479
# Epoch 2/20
# 243/243 - 6s - loss: 7.4932 - accuracy: 0.8934
# Epoch 3/20
# 243/243 - 6s - loss: 2.8965 - accuracy: 0.9526
# Epoch 4/20
# 243/243 - 6s - loss: 2.1178 - accuracy: 0.9748
# Epoch 5/20
# 243/243 - 6s - loss: 1.0841 - accuracy: 0.9830
# Epoch 6/20
# 243/243 - 6s - loss: 0.8461 - accuracy: 0.9861
# Epoch 7/20
# 243/243 - 6s - loss: 0.4248 - accuracy: 0.9912
# Epoch 8/20
# 243/243 - 6s - loss: 0.8354 - accuracy: 0.9954
# Epoch 9/20
# 243/243 - 6s - loss: 1.2096 - accuracy: 0.9876
# Epoch 10/20
# 243/243 - 6s - loss: 1.0678 - accuracy: 0.9938
# Epoch 11/20
# 243/243 - 6s - loss: 0.3828 - accuracy: 0.9969
# Epoch 12/20
# 243/243 - 6s - loss: 1.6303 - accuracy: 0.9897
# Epoch 13/20
# 243/243 - 6s - loss: 1.9645 - accuracy: 0.9912
# Epoch 14/20
# 243/243 - 6s - loss: 3.7743 - accuracy: 0.9866
# Epoch 15/20
# 243/243 - 6s - loss: 0.8865 - accuracy: 0.9943
# Epoch 16/20
# 243/243 - 6s - loss: 1.4609 - accuracy: 0.9892
# Epoch 17/20
# 243/243 - 6s - loss: 0.9723 - accuracy: 0.9949
# Epoch 18/20
# 243/243 - 6s - loss: 0.7183 - accuracy: 0.9959
# Epoch 19/20
# 243/243 - 6s - loss: 2.5863 - accuracy: 0.9938
# Epoch 20/20
# 243/243 - 6s - loss: 2.9523 - accuracy: 0.9923
# 62/62 - 2s - loss: 167.0145 - accuracy: 0.7710
# Epoch 1/20
# 246/246 - 7s - loss: 42.2759 - accuracy: 0.5563
# Epoch 2/20
# 246/246 - 6s - loss: 8.4351 - accuracy: 0.8389
# Epoch 3/20
# 246/246 - 6s - loss: 2.7229 - accuracy: 0.9521
# Epoch 4/20
# 246/246 - 6s - loss: 1.0370 - accuracy: 0.9765
# Epoch 5/20
# 246/246 - 6s - loss: 0.5277 - accuracy: 0.9842
# Epoch 6/20
# 246/246 - 6s - loss: 0.8074 - accuracy: 0.9857
# Epoch 7/20
# 246/246 - 6s - loss: 0.7004 - accuracy: 0.9867
# Epoch 8/20
# 246/246 - 6s - loss: 2.0154 - accuracy: 0.9776
# Epoch 9/20
# 246/246 - 6s - loss: 3.0271 - accuracy: 0.9765
# Epoch 10/20
# 246/246 - 6s - loss: 3.3932 - accuracy: 0.9837
# Epoch 11/20
# 246/246 - 6s - loss: 1.7098 - accuracy: 0.9857
# Epoch 12/20
# 246/246 - 6s - loss: 1.2975 - accuracy: 0.9878
# Epoch 13/20
# 246/246 - 6s - loss: 1.4306 - accuracy: 0.9944
# Epoch 14/20
# 246/246 - 6s - loss: 0.6071 - accuracy: 0.9949
# Epoch 15/20
# 246/246 - 6s - loss: 0.8028 - accuracy: 0.9944
# Epoch 16/20
# 246/246 - 6s - loss: 1.6441 - accuracy: 0.9934
# Epoch 17/20
# 246/246 - 6s - loss: 0.3327 - accuracy: 0.9959
# Epoch 18/20
# 246/246 - 6s - loss: 2.8619 - accuracy: 0.9908
# Epoch 19/20
# 246/246 - 6s - loss: 1.0675 - accuracy: 0.9929
# Epoch 20/20
# 246/246 - 6s - loss: 1.3006 - accuracy: 0.9939
# 59/59 - 2s - loss: 48.1183 - accuracy: 0.8149
# Epoch 1/40
# 152/152 - 8s - loss: 48.0347 - accuracy: 0.5763
# Epoch 2/40
# 152/152 - 6s - loss: 10.5063 - accuracy: 0.8573
# Epoch 3/40
# 152/152 - 6s - loss: 3.5099 - accuracy: 0.9441
# Epoch 4/40
# 152/152 - 6s - loss: 2.0895 - accuracy: 0.9646
# Epoch 5/40
# 152/152 - 6s - loss: 1.8338 - accuracy: 0.9761
# Epoch 6/40
# 152/152 - 6s - loss: 0.9015 - accuracy: 0.9848
# Epoch 7/40
# 152/152 - 6s - loss: 0.8156 - accuracy: 0.9864
# Epoch 8/40
# 152/152 - 6s - loss: 0.2993 - accuracy: 0.9901
# Epoch 9/40
# 152/152 - 6s - loss: 0.5202 - accuracy: 0.9914
# Epoch 10/40
# 152/152 - 6s - loss: 0.4371 - accuracy: 0.9938
# Epoch 11/40
# 152/152 - 6s - loss: 0.0861 - accuracy: 0.9988
# Epoch 12/40
# 152/152 - 6s - loss: 0.3853 - accuracy: 0.9938
# Epoch 13/40
# 152/152 - 6s - loss: 0.3985 - accuracy: 0.9951
# Epoch 14/40
# 152/152 - 6s - loss: 0.0721 - accuracy: 0.9971
# Epoch 15/40
# 152/152 - 6s - loss: 0.1906 - accuracy: 0.9963
# Epoch 16/40
# 152/152 - 6s - loss: 0.2019 - accuracy: 0.9979
# Epoch 17/40
# 152/152 - 6s - loss: 0.0324 - accuracy: 0.9988
# Epoch 18/40
# 152/152 - 6s - loss: 0.3238 - accuracy: 0.9959
# Epoch 19/40
# 152/152 - 6s - loss: 0.2005 - accuracy: 0.9967
# Epoch 20/40
# 152/152 - 6s - loss: 0.2651 - accuracy: 0.9967
# Epoch 21/40
# 152/152 - 6s - loss: 0.1083 - accuracy: 0.9984
# Epoch 22/40
# 152/152 - 6s - loss: 0.1092 - accuracy: 0.9975
# Epoch 23/40
# 152/152 - 6s - loss: 0.0984 - accuracy: 0.9988
# Epoch 24/40
# 152/152 - 6s - loss: 0.1923 - accuracy: 0.9975
# Epoch 25/40
# 152/152 - 6s - loss: 0.1473 - accuracy: 0.9971
# Epoch 26/40
# 152/152 - 6s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 27/40
# 152/152 - 6s - loss: 0.0649 - accuracy: 0.9984
# Epoch 28/40
# 152/152 - 6s - loss: 0.0076 - accuracy: 0.9996
# Epoch 29/40
# 152/152 - 6s - loss: 0.0543 - accuracy: 0.9992
# Epoch 30/40
# 152/152 - 6s - loss: 0.0470 - accuracy: 0.9988
# Epoch 31/40
# 152/152 - 6s - loss: 0.0595 - accuracy: 0.9984
# Epoch 32/40
# 152/152 - 6s - loss: 0.0566 - accuracy: 0.9996
# Epoch 33/40
# 152/152 - 6s - loss: 0.0207 - accuracy: 0.9992
# Epoch 34/40
# 152/152 - 6s - loss: 4.8544e-08 - accuracy: 1.0000
# Epoch 35/40
# 152/152 - 6s - loss: 0.0684 - accuracy: 0.9975
# Epoch 36/40
# 152/152 - 6s - loss: 0.0028 - accuracy: 0.9996
# Epoch 37/40
# 152/152 - 6s - loss: 1.8092e-05 - accuracy: 1.0000
# Epoch 38/40
# 152/152 - 6s - loss: 0.0858 - accuracy: 0.9984
# Epoch 39/40
# 152/152 - 6s - loss: 0.0302 - accuracy: 0.9992
# Epoch 40/40
# 152/152 - 6s - loss: 0.0884 - accuracy: 0.9988
# {'mean_fit_time': array([172.73678241, 251.68956552,  92.84433484,  43.08721395,
#         87.8343935 , 238.02902455, 156.81609411, 186.78154583,
#        129.51902986, 123.23425279]), 'std_fit_time': array([ 1.42637406, 16.84204228,  0.77432925,  1.7407609 ,  0.69691407,
#        13.60790103,  1.35061239,  9.49877345,  1.15150123, 11.23810965]), 'mean_score_time': array([1.87097373, 2.15197711, 1.59408531, 1.80579824, 1.49258609,
#        1.8086658 , 1.38561821, 1.4722115 , 1.82015595, 2.05451312]), 'std_score_time': array([0.42929323, 0.44664511, 0.18495609, 0.67906328, 0.0519166 ,
#        0.07222223, 0.04725695, 0.05444902, 0.04911443, 0.4851764 ]), 'param_optimizer': masked_array(data=[<keras.optimizer_v2.rmsprop.RMSprop object at 0x7f7c2b7a9bd0>,
#                    <keras.optimizer_v2.rmsprop.RMSprop object at 0x7f7c2b7a9bd0>,
#                    'rmsprop',
#                    <keras.optimizer_v2.gradient_descent.SGD object at 0x7f7bbf754590>,
#                    <keras.optimizer_v2.rmsprop.RMSprop object at 0x7f7c2b7a9bd0>,
#                    'adam',
#                    <keras.optimizer_v2.rmsprop.RMSprop object at 0x7f7c2b7a9bd0>,
#                    'rmsprop', 'rmsprop', 'adam'],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False],
#        fill_value='?',
#             dtype=object), 'param_epochs': masked_array(data=[40, 40, 20, 10, 20, 40, 40, 40, 20, 20],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False],
#        fill_value='?',
#             dtype=object), 'param_batch_size': masked_array(data=[16, 8, 16, 32, 16, 8, 32, 16, 8, 8],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False],
#        fill_value='?',
#             dtype=object), 'params': [{'optimizer': <keras.optimizer_v2.rmsprop.RMSprop object at 0x7f7c2b7a9bd0>, 'epochs': 40, 'batch_size': 16}, {'optimizer': <keras.optimizer_v2.rmsprop.RMSprop object at 0x7f7c2b7a9bd0>, 'epochs': 40, 'batch_size': 8}, {'optimizer': 'rmsprop', 'epochs': 20, 'batch_size': 16}, {'optimizer': <keras.optimizer_v2.gradient_descent.SGD object at 0x7f7bbf754590>, 'epochs': 10, 'batch_size': 32}, {'optimizer': <keras.optimizer_v2.rmsprop.RMSprop object at 0x7f7c2b7a9bd0>, 'epochs': 20, 'batch_size': 16}, {'optimizer': 'adam', 'epochs': 40, 'batch_size': 8}, {'optimizer': <keras.optimizer_v2.rmsprop.RMSprop object at 0x7f7c2b7a9bd0>, 'epochs': 40, 'batch_size': 32}, {'optimizer': 'rmsprop', 'epochs': 40, 'batch_size': 16}, {'optimizer': 'rmsprop', 'epochs': 20, 'batch_size': 8}, {'optimizer': 'adam', 'epochs': 20, 'batch_size': 8}], 'split0_test_score': array([0.3868472 , 0.3868472 , 0.88394582, 0.82011604, 0.3868472 ,
#        0.8916828 , 0.3868472 , 0.90715665, 0.86847198, 0.83365571]), 'split1_test_score': array([0.38626608, 0.3004292 , 0.87124461, 0.89914161, 0.3004292 ,
#        0.90557939, 0.3004292 , 0.95493561, 0.91416311, 0.92489272]), 'split2_test_score': array([0.24539877, 0.24539877, 0.70552146, 0.6789366 , 0.24539877,
#        0.65848672, 0.24539877, 0.74642128, 0.74028629, 0.67075664]), 'split3_test_score': array([0.32719836, 0.32719836, 0.81186092, 0.79550099, 0.32719836,
#        0.81186092, 0.28629857, 0.7443763 , 0.83026582, 0.77096117]), 'split4_test_score': array([0.29787233, 0.29787233, 0.8425532 , 0.84468085, 0.29787233,
#        0.82765955, 0.29787233, 0.88723403, 0.85106385, 0.8148936 ]), 'mean_test_score': array([0.32871655, 0.31154917, 0.8230252 , 0.80767522, 0.31154917,
#        0.81905388, 0.30336922, 0.84802477, 0.84085021, 0.80303197]), 'std_test_score': array([0.0540123 , 0.04604623, 0.06379584, 0.07295497, 0.04604623,
#        0.08794229, 0.04617231, 0.08663734, 0.05738849, 0.08301067]), 'rank_test_score': array([ 7,  8,  3,  5,  8,  4, 10,  1,  2,  6], dtype=int32)}
#
# 0.8480247735977173
#
# {'optimizer': 'rmsprop', 'epochs': 40, 'batch_size': 16}
#
# 7
#
# <function _passthrough_scorer at 0x7f7c14e13a70>
# End setting up
# Begin training with the best parameters
# Epoch 1/43
# 152/152 - 7s - loss: 39.5984 - accuracy: 0.5948
# INFO:tensorflow:Assets written to: weight.hdf55/assets
# Epoch 2/43
# 152/152 - 6s - loss: 7.4006 - accuracy: 0.8893
# INFO:tensorflow:Assets written to: weight.hdf55/assets
# Epoch 3/43
# 152/152 - 6s - loss: 2.9919 - accuracy: 0.9527
# INFO:tensorflow:Assets written to: weight.hdf55/assets
# Epoch 4/43
# 152/152 - 6s - loss: 2.3162 - accuracy: 0.9667
# INFO:tensorflow:Assets written to: weight.hdf55/assets
# Epoch 5/43
# 152/152 - 6s - loss: 1.2307 - accuracy: 0.9761
# INFO:tensorflow:Assets written to: weight.hdf55/assets
# Epoch 6/43
# 152/152 - 6s - loss: 1.0380 - accuracy: 0.9844
# INFO:tensorflow:Assets written to: weight.hdf55/assets
# Epoch 7/43
# 152/152 - 6s - loss: 0.6501 - accuracy: 0.9885
# INFO:tensorflow:Assets written to: weight.hdf55/assets
# Epoch 8/43
# 152/152 - 6s - loss: 0.5873 - accuracy: 0.9901
# INFO:tensorflow:Assets written to: weight.hdf55/assets
# Epoch 9/43
# 152/152 - 6s - loss: 0.5353 - accuracy: 0.9926
# INFO:tensorflow:Assets written to: weight.hdf55/assets
# Epoch 10/43
# 152/152 - 6s - loss: 0.5445 - accuracy: 0.9918
# Epoch 11/43
# 152/152 - 6s - loss: 0.5733 - accuracy: 0.9901
# Epoch 12/43
# 152/152 - 6s - loss: 0.4436 - accuracy: 0.9922
# Epoch 13/43
# 152/152 - 6s - loss: 0.2416 - accuracy: 0.9947
# INFO:tensorflow:Assets written to: weight.hdf55/assets
# Epoch 14/43
# 152/152 - 6s - loss: 0.1310 - accuracy: 0.9979
# INFO:tensorflow:Assets written to: weight.hdf55/assets
# Epoch 15/43
# 152/152 - 6s - loss: 0.0548 - accuracy: 0.9979
# Epoch 16/43
# 152/152 - 6s - loss: 0.2683 - accuracy: 0.9975
# Epoch 17/43
# 152/152 - 6s - loss: 0.0453 - accuracy: 0.9992
# INFO:tensorflow:Assets written to: weight.hdf55/assets
# Epoch 18/43
# 152/152 - 6s - loss: 0.0700 - accuracy: 0.9975
# Epoch 19/43
# 152/152 - 6s - loss: 0.0309 - accuracy: 0.9992
# Epoch 20/43
# 152/152 - 6s - loss: 0.2246 - accuracy: 0.9979
# Epoch 21/43
# 152/152 - 6s - loss: 0.0224 - accuracy: 0.9992
# Epoch 22/43
# 152/152 - 6s - loss: 0.1022 - accuracy: 0.9975
# End training

# %%
test_func()
# Out:
# 100%|██████████| 32/32 [00:15<00:00,  2.02it/s]
# 81.25
